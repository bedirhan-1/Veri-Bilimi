# %% [markdown]
# # Element Operating

# %%
import numpy as np
import pandas as pd

# %%
s1 = np.random.randint(10, size = 5)
s2 = np.random.randint(10, size = 5)
s3 = np.random.randint(10, size = 5)

# %%
sozluk = {"var1":s1, "var2":s2, "var3":s3}
sozluk
# Out:
# {'var1': array([5, 8, 4, 7, 1]),
#  'var2': array([4, 6, 8, 6, 8]),
#  'var3': array([3, 1, 9, 8, 9])}

# %%
df = pd.DataFrame(sozluk)

# %%
df
# Out:
#    var1  var2  var3
# 0     5     4     3
# 1     8     6     1
# 2     4     8     9
# 3     7     6     8
# 4     1     8     9

# %%
 df[0:1]
# Out:
#    var1  var2  var3
# 0     5     4     3

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.index = ["a","b","c","d","e"]

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df["c":"e"]
# Out:
#    var1  var2  var3
# c     4     8     9
# d     7     6     8
# e     1     8     9

# %%
df.drop("a", axis = 0)
# Out:
#    var1  var2  var3
# b     8     6     1
# c     4     8     9
# d     7     6     8
# e     1     8     9

# %%
df
# Out:
#    var1  var2  var3
# a     5     4     3
# b     8     6     1
# c     4     8     9
# d     7     6     8
# e     1     8     9

# %%
df.drop("a", axis = 0, inplace = True)

# %%
df
# Out:
#    var1  var2  var3
# b     8     6     1
# c     4     8     9
# d     7     6     8
# e     1     8     9

# %%
l = ["c","e"]

# %%
df.drop(l, axis = 0)
# Out:
#    var1  var2  var3
# b     8     6     1
# d     7     6     8

# %%
"var1" in df
# Out:
# True

# %%
l = ["var1","var4","var2"]

# %%
for i in l:
    print(i in df)
# Out:
# True
# False
# True

# %%
df
# Out:
#    var1  var2  var3
# b     8     6     1
# c     4     8     9
# d     7     6     8
# e     1     8     9

# %%
df["var4"] = [1,2,3,4]

# %%
df
# Out:
#    var1  var2  var3  var4
# b     8     6     1     1
# c     4     8     9     2
# d     7     6     8     3
# e     1     8     9     4

# %%
df.drop("var4", axis = 1 , inplace = True)

# %%
df
# Out:
#    var1  var2  var3
# b     8     6     1
# c     4     8     9
# d     7     6     8
# e     1     8     9

# %%
l = ["var1","var2"]

# %%
df.drop(l, axis = 1)
# Out:
#    var3
# b     1
# c     9
# d     8
# e     9

# %%
df
# Out:
#    var1  var2  var3
# b     8     6     1
# c     4     8     9
# d     7     6     8
# e     1     8     9
