# %% [markdown]
# # Creatin a Pandas Serie

# %%
import pandas as pd

# %%
pd.Series([15,34,45,76,23]) # index & data
# Out:
# 0    15
# 1    34
# 2    45
# 3    76
# 4    23
# dtype: int64

# %%
serie = pd.Series([10,43,88,3,2,5])

# %%
type(serie)
# Out:
# pandas.core.series.Series

# %%
serie.axes
# Out:
# [RangeIndex(start=0, stop=6, step=1)]

# %%
serie.dtype
# Out:
# dtype('int64')

# %%
serie.size
# Out:
# 6

# %%
serie.ndim
# Out:
# 1

# %%
serie.values
# Out:
# array([10, 43, 88,  3,  2,  5], dtype=int64)

# %%
serie.head
# Out:
# <bound method NDFrame.head of 0    10
# 1    43
# 2    88
# 3     3
# 4     2
# 5     5
# dtype: int64>

# %%
serie.head(3)
# Out:
# 0    10
# 1    43
# 2    88
# dtype: int64

# %%
serie.tail(3)
# Out:
# 3    3
# 4    2
# 5    5
# dtype: int64

# %%
# index changing

# %%
pd.Series([99,22,332,94,5])
# Out:
# 0     99
# 1     22
# 2    332
# 3     94
# 4      5
# dtype: int64

# %%
pd.Series([99,22,332,94,5], index = [1,3,5,7,9])
# Out:
# 1     99
# 3     22
# 5    332
# 7     94
# 9      5
# dtype: int64

# %%
serie = pd.Series([99,22,332,94,5], index = ["a","b","c","d","e"])

# %%
serie["a"]
# Out:
# 99

# %%
serie["a":"c"]
# Out:
# a     99
# b     22
# c    332
# dtype: int64

# %%
dictionary = pd.Series({"reg":10, "log":11, "cart": 12})

# %%
serie = pd.Series(dictionary)

# %%
serie
# Out:
# reg     10
# log     11
# cart    12
# dtype: int64

# %% [markdown]
# # Merging two series to create a new series

# %%
pd.concat([serie, serie])
# Out:
# reg     10
# log     11
# cart    12
# reg     10
# log     11
# cart    12
# dtype: int64
