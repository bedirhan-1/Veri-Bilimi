# %% [markdown]
# # Element operations

# %%
import numpy as np
import pandas as pd

# %%
array = np.array([1,2,33,444,75])

serie = pd.Series(array)

# %%
serie
# Out:
# 0      1
# 1      2
# 2     33
# 3    444
# 4     75
# dtype: int32

# %%
serie[0:3]
# Out:
# 0     1
# 1     2
# 2    33
# dtype: int32

# %%
serie = pd.Series([121,200,150,99], index=["reg","log","cart","rf"])
serie
# Out:
# reg     121
# log     200
# cart    150
# rf       99
# dtype: int64

# %%
serie.keys
# Out:
# <bound method Series.keys of reg     121
# log     200
# cart    150
# rf       99
# dtype: int64>

# %%
list(serie.items())
# Out:
# [('reg', 121), ('log', 200), ('cart', 150), ('rf', 99)]

# %%
serie.values
# Out:
# array([121, 200, 150,  99], dtype=int64)

# %%
serie.index
# Out:
# Index(['reg', 'log', 'cart', 'rf'], dtype='object')

# %%
"reg" in serie
# Out:
# True

# %%
"a" in serie
# Out:
# False

# %%
serie["reg"]
# Out:
# 121

# %%
# fancy element

# %%
serie[["rf", "reg"]]
# Out:
# rf      99
# reg    121
# dtype: int64

# %%
serie["reg"] = 130

# %%
serie
# Out:
# reg     130
# log     200
# cart    150
# rf       99
# dtype: int64
