# %%
import numpy as np

populasyon = np.random.randint(0, 80, 100)

populasyon
# Out:
# array([46, 77, 22, 61, 33,  4,  1, 37, 29, 16, 40, 35, 17, 36, 43, 70,  5,
#        46, 32,  6, 66, 55, 19, 61, 45, 79, 73, 53, 44, 73, 72, 29, 34, 33,
#        20, 74, 62, 71, 31, 20, 21, 67, 64, 37, 43, 25, 49,  9,  8, 37, 30,
#         2, 17, 24, 66, 10, 76, 64, 59, 62, 28, 33, 11, 38, 32, 32, 15,  8,
#        53, 15, 60, 25, 71, 25, 45, 19, 40, 24,  0, 44, 70, 45, 68, 63, 30,
#        48,  8, 31, 59, 29, 34, 79,  1, 20, 12, 37, 48,  6, 43, 75])

# %%
# Örneklem çekimi
np.random.seed(115)
orneklem = np.random.choice(a = populasyon, size = 100)
orneklem
# Out:
# array([32, 34, 43,  1,  5, 79, 43,  6, 29, 67, 11, 49, 17, 32, 75, 37, 43,
#        11, 73, 37, 22,  8, 66, 10,  4, 45, 48, 38, 24,  6, 29, 22, 34, 46,
#         2, 33, 19, 37, 67, 71, 21,  1, 31, 21, 45, 71, 59, 37, 29, 24, 46,
#        32, 25,  1, 71, 25, 15, 61, 67, 37, 62, 31, 43, 33, 79, 22, 24, 40,
#        17, 37, 73, 33, 37, 37,  1, 40, 11, 73, 61, 10, 59, 12, 60, 19,  4,
#        32, 28, 19, 37, 32, 20, 29,  1, 34, 34, 71, 43, 24, 37, 12])

# %%
orneklem.mean()
# Out:
# 34.45

# %%
populasyon.mean()
# Out:
# 38.64
