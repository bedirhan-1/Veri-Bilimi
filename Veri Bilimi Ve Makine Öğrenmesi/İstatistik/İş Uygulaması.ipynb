# %% [markdown]
# # İş Uygulaması: Fiyat Stratejisi Karar Destek

# %%
import numpy as np

fiyatlar = np.random.randint(1000, 7500, 200)
fiyatlar.mean()
# Out:
# 4584.425

# %%
fiyatlar
# Out:
# array([4163, 3356, 5323, 5148, 2443, 6878, 1130, 4039, 6821, 4950, 5109,
#        2142, 7404, 5790, 3497, 6586, 3584, 2816, 6140, 6647, 1177, 7281,
#        5129, 2645, 5953, 5284, 4699, 5066, 2050, 4449, 4167, 5263, 4346,
#        1408, 7394, 4748, 4675, 2091, 6043, 1582, 5388, 5655, 1356, 2015,
#        2067, 5072, 4819, 1588, 4253, 4925, 7166, 7342, 4161, 2791, 4999,
#        3926, 3589, 3523, 3606, 5598, 5984, 7062, 1388, 6897, 1915, 2004,
#        6362, 3926, 3102, 6908, 1873, 4961, 2200, 4421, 6916, 6844, 4133,
#        2334, 6754, 1617, 1382, 2722, 7139, 3828, 6048, 2114, 3867, 5770,
#        1147, 3239, 2963, 7061, 5196, 4088, 2423, 6869, 2154, 4777, 4729,
#        3889, 4496, 3346, 4789, 7288, 2534, 6945, 5886, 1951, 7300, 3545,
#        2011, 3356, 1446, 4754, 6828, 2714, 3782, 7283, 1701, 4041, 4620,
#        4121, 7099, 7347, 5110, 5295, 3419, 6347, 4290, 7172, 5945, 5840,
#        2687, 5511, 5972, 4701, 5730, 7445, 6424, 1527, 3397, 7491, 6702,
# ...

# %%
import statsmodels.stats.api as sms
sms.DescrStatsW(fiyatlar).tconfint_mean()
# Out:
# (4324.988726955471, 4843.861273044529)
