# %% [markdown]
# # Büyük Sayılar Yasası

# %%
rng.randint(0, 2, size = 5)
# Out:
# array([1, 0, 0, 0, 1])

# %%
import numpy as np
rng = np.random.RandomState(123)
for i in np.arange(1, 21):
    deney_sayisi =2**i
    yazi_turalar = rng.randint(0, 2, size = deney_sayisi)
    yazi_olasiliklari = np.mean(yazi_turalar)
    print("Atış Sayısı:", deney_sayisi,"---",'Yazı olasılığı : %2f' %(yazi_olasiliklari*100))
# Out:
# Atış Sayısı: 2 --- Yazı olasılığı : 50.000000
# Atış Sayısı: 4 --- Yazı olasılığı : 0.000000
# Atış Sayısı: 8 --- Yazı olasılığı : 62.500000
# Atış Sayısı: 16 --- Yazı olasılığı : 43.750000
# Atış Sayısı: 32 --- Yazı olasılığı : 46.875000
# Atış Sayısı: 64 --- Yazı olasılığı : 56.250000
# Atış Sayısı: 128 --- Yazı olasılığı : 50.781250
# Atış Sayısı: 256 --- Yazı olasılığı : 52.734375
# Atış Sayısı: 512 --- Yazı olasılığı : 52.929688
# Atış Sayısı: 1024 --- Yazı olasılığı : 50.195312
# Atış Sayısı: 2048 --- Yazı olasılığı : 48.583984
# Atış Sayısı: 4096 --- Yazı olasılığı : 49.487305
# Atış Sayısı: 8192 --- Yazı olasılığı : 49.584961
# Atış Sayısı: 16384 --- Yazı olasılığı : 49.957275
# Atış Sayısı: 32768 --- Yazı olasılığı : 50.000000
# Atış Sayısı: 65536 --- Yazı olasılığı : 49.678040
# Atış Sayısı: 131072 --- Yazı olasılığı : 49.973297
# Atış Sayısı: 262144 --- Yazı olasılığı : 50.125504
# Atış Sayısı: 524288 --- Yazı olasılığı : 50.012970
# Atış Sayısı: 1048576 --- Yazı olasılığı : 50.090027
