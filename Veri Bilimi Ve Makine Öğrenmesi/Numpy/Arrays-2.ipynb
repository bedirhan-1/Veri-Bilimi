# %% [markdown]
# * ndim number of dimensions
# * shape : dimension information
# * size : total number of elements
# * dtype : data type of the array

# %%
import numpy as np

# %%
a = np.random.randint(10, size = 10)

# %%
a
# Out:
# array([2, 0, 3, 8, 1, 9, 0, 9, 4, 6])

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (10,)

# %%
a.dtype
# Out:
# dtype('int32')

# %%
b = np.random.randint(10, size = (3,5))

# %%
b
# Out:
# array([[1, 1, 1, 1, 1],
#        [4, 0, 6, 9, 3],
#        [8, 2, 7, 3, 3]])

# %%
b. ndim
# Out:
# 2

# %%
b.shape
# Out:
# (3, 5)

# %%
b.size
# Out:
# 15

# %%
b.dtype
# Out:
# dtype('int32')
