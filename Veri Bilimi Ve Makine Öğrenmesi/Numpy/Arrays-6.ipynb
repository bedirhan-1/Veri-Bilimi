# %% [markdown]
# # Sorting

# %%
import numpy as np

# %%
v = np.array([2,1,5,7,3,4,6])

# %%
v
# Out:
# array([2, 1, 5, 7, 3, 4, 6])

# %%
np.sort(v)
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
v
# Out:
# array([2, 1, 5, 7, 3, 4, 6])

# %%
v.sort()

# %%
v
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %% [markdown]
# #### two dimension

# %%
m = np.random.normal(20, 5, (3,3))

# %%
m
# Out:
# array([[24.33931436, 17.74334213, 18.22362083],
#        [12.37307965, 18.48550716, 15.08875555],
#        [21.59451148, 27.28298926, 20.71224298]])

# %%
np.sort(m, axis = 1)
# Out:
# array([[17.74334213, 18.22362083, 24.33931436],
#        [12.37307965, 15.08875555, 18.48550716],
#        [20.71224298, 21.59451148, 27.28298926]])

# %%
np.sort(m, axis = 0)
# Out:
# array([[12.37307965, 17.74334213, 15.08875555],
#        [21.59451148, 18.48550716, 18.22362083],
#        [24.33931436, 27.28298926, 20.71224298]])
